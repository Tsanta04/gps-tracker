# %%
# !pip install paho-mqtt
# Out:
# Collecting paho-mqtt
#   Using cached paho_mqtt-2.1.0-py3-none-any.whl.metadata (23 kB)
# Using cached paho_mqtt-2.1.0-py3-none-any.whl (67 kB)
# Installing collected packages: paho-mqtt
# Successfully installed paho-mqtt-2.1.0
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import time
import json
import random
import ssl
import paho.mqtt.client as mqtt
from datetime import datetime

# %%
BROKER = "e792f3c61e8648d2bd1822c6d1910301.s1.eu.hivemq.cloud"
PORT = 8883
USERNAME = "GPS_ESP"
PASSWORD = "TsantaMirindra1"

DEVICE_ID = "device001"
CLIENT_ID = "location-subscriber"
TOPIC = "iot/"+DEVICE_ID+"/location"

# Position de départ (ex: Antananarivo / Larissa / etc.)
BASE_LAT = -18.8792
BASE_LNG = 47.5079

# %%
def on_connect(client, userdata, flags, rc):
    if rc == 0:
        print("Connected to HiveMQ Cloud")
        print(TOPIC)
    else:
        print(f"Connection failed (code {rc})")

# %%
client = mqtt.Client(client_id=DEVICE_ID)
client.username_pw_set(USERNAME, PASSWORD)
client.tls_set(cert_reqs=ssl.CERT_REQUIRED)

client.on_connect = on_connect
client.connect(BROKER, PORT)
client.loop_start()
# Out:
# C:\Users\WINDOWS 10\AppData\Local\Temp\ipykernel_16908\2261359266.py:1: DeprecationWarning: Callback API version 1 is deprecated, update to latest version
#   client = mqtt.Client(client_id=DEVICE_ID)
# <MQTTErrorCode.MQTT_ERR_SUCCESS: 0>

# %%
# ================= TRAJET =================
GAIOPOLIS = (-18.880500, 47.508900)
CENTRAL_SQUARE = (-18.879200, 47.507000)

STEPS = 50          # nombre de points (plus = plus lent et réaliste)
DELAY = 2           # secondes entre chaque position

try:
    for i in range(STEPS + 1):
        # interpolation linéaire
        lat = GAIOPOLIS[0] + (CENTRAL_SQUARE[0] - GAIOPOLIS[0]) * i / STEPS
        lng = GAIOPOLIS[1] + (CENTRAL_SQUARE[1] - GAIOPOLIS[1]) * i / STEPS

        payload = {
            "device_id": DEVICE_ID,
            "latitude": round(lat, 6),
            "longitude": round(lng, 6),
            "timestamp": datetime.utcnow().isoformat()
        }

        client.publish(TOPIC, json.dumps(payload), qos=1)
        print("Sent:", payload)

        time.sleep(DELAY)

except KeyboardInterrupt:
    print("\nStopped by user")

finally:
    client.loop_stop()
    client.disconnect()
# Out:
# C:\Users\WINDOWS 10\AppData\Local\Temp\ipykernel_16908\4092807124.py:18: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   "timestamp": datetime.utcnow().isoformat()
# Sent: {'device_id': 'device001', 'latitude': -18.8805, 'longitude': 47.5089, 'timestamp': '2026-01-12T07:39:35.654498'}
# Connected to HiveMQ Cloud
# iot/device001/location
# Sent: {'device_id': 'device001', 'latitude': -18.880474, 'longitude': 47.508862, 'timestamp': '2026-01-12T07:39:37.656125'}
# Sent: {'device_id': 'device001', 'latitude': -18.880448, 'longitude': 47.508824, 'timestamp': '2026-01-12T07:39:39.656941'}
# Sent: {'device_id': 'device001', 'latitude': -18.880422, 'longitude': 47.508786, 'timestamp': '2026-01-12T07:39:41.657890'}
# Sent: {'device_id': 'device001', 'latitude': -18.880396, 'longitude': 47.508748, 'timestamp': '2026-01-12T07:39:43.660626'}
# Sent: {'device_id': 'device001', 'latitude': -18.88037, 'longitude': 47.50871, 'timestamp': '2026-01-12T07:39:45.662039'}
# Sent: {'device_id': 'device001', 'latitude': -18.880344, 'longitude': 47.508672, 'timestamp': '2026-01-12T07:39:47.663640'}
# Sent: {'device_id': 'device001', 'latitude': -18.880318, 'longitude': 47.508634, 'timestamp': '2026-01-12T07:39:49.665171'}
# Sent: {'device_id': 'device001', 'latitude': -18.880292, 'longitude': 47.508596, 'timestamp': '2026-01-12T07:39:51.666188'}
# Sent: {'device_id': 'device001', 'latitude': -18.880266, 'longitude': 47.508558, 'timestamp': '2026-01-12T07:39:53.667006'}
# Sent: {'device_id': 'device001', 'latitude': -18.88024, 'longitude': 47.50852, 'timestamp': '2026-01-12T07:39:55.668427'}
# Sent: {'device_id': 'device001', 'latitude': -18.880214, 'longitude': 47.508482, 'timestamp': '2026-01-12T07:39:57.669994'}
# Sent: {'device_id': 'device001', 'latitude': -18.880188, 'longitude': 47.508444, 'timestamp': '2026-01-12T07:39:59.671746'}
# Sent: {'device_id': 'device001', 'latitude': -18.880162, 'longitude': 47.508406, 'timestamp': '2026-01-12T07:40:01.673110'}
# Sent: {'device_id': 'device001', 'latitude': -18.880136, 'longitude': 47.508368, 'timestamp': '2026-01-12T07:40:03.674655'}
# Sent: {'device_id': 'device001', 'latitude': -18.88011, 'longitude': 47.50833, 'timestamp': '2026-01-12T07:40:05.675517'}
# Sent: {'device_id': 'device001', 'latitude': -18.880084, 'longitude': 47.508292, 'timestamp': '2026-01-12T07:40:07.676657'}
# Sent: {'device_id': 'device001', 'latitude': -18.880058, 'longitude': 47.508254, 'timestamp': '2026-01-12T07:40:09.677917'}
# Sent: {'device_id': 'device001', 'latitude': -18.880032, 'longitude': 47.508216, 'timestamp': '2026-01-12T07:40:11.679094'}
# Sent: {'device_id': 'device001', 'latitude': -18.880006, 'longitude': 47.508178, 'timestamp': '2026-01-12T07:40:13.679931'}
# Sent: {'device_id': 'device001', 'latitude': -18.87998, 'longitude': 47.50814, 'timestamp': '2026-01-12T07:40:15.681173'}
# Sent: {'device_id': 'device001', 'latitude': -18.879954, 'longitude': 47.508102, 'timestamp': '2026-01-12T07:40:17.682949'}
# Sent: {'device_id': 'device001', 'latitude': -18.879928, 'longitude': 47.508064, 'timestamp': '2026-01-12T07:40:19.684473'}
# Sent: {'device_id': 'device001', 'latitude': -18.879902, 'longitude': 47.508026, 'timestamp': '2026-01-12T07:40:21.685858'}
# Sent: {'device_id': 'device001', 'latitude': -18.879876, 'longitude': 47.507988, 'timestamp': '2026-01-12T07:40:23.687078'}
# Sent: {'device_id': 'device001', 'latitude': -18.87985, 'longitude': 47.50795, 'timestamp': '2026-01-12T07:40:25.688036'}
# Sent: {'device_id': 'device001', 'latitude': -18.879824, 'longitude': 47.507912, 'timestamp': '2026-01-12T07:40:27.689608'}
# Sent: {'device_id': 'device001', 'latitude': -18.879798, 'longitude': 47.507874, 'timestamp': '2026-01-12T07:40:29.690602'}
# Sent: {'device_id': 'device001', 'latitude': -18.879772, 'longitude': 47.507836, 'timestamp': '2026-01-12T07:40:31.691930'}
# Sent: {'device_id': 'device001', 'latitude': -18.879746, 'longitude': 47.507798, 'timestamp': '2026-01-12T07:40:33.693208'}
# Sent: {'device_id': 'device001', 'latitude': -18.87972, 'longitude': 47.50776, 'timestamp': '2026-01-12T07:40:35.694839'}
# Sent: {'device_id': 'device001', 'latitude': -18.879694, 'longitude': 47.507722, 'timestamp': '2026-01-12T07:40:37.696833'}
# Sent: {'device_id': 'device001', 'latitude': -18.879668, 'longitude': 47.507684, 'timestamp': '2026-01-12T07:40:39.698366'}
# Sent: {'device_id': 'device001', 'latitude': -18.879642, 'longitude': 47.507646, 'timestamp': '2026-01-12T07:40:41.699854'}
# Sent: {'device_id': 'device001', 'latitude': -18.879616, 'longitude': 47.507608, 'timestamp': '2026-01-12T07:40:43.701355'}
# Sent: {'device_id': 'device001', 'latitude': -18.87959, 'longitude': 47.50757, 'timestamp': '2026-01-12T07:40:45.703504'}
# Sent: {'device_id': 'device001', 'latitude': -18.879564, 'longitude': 47.507532, 'timestamp': '2026-01-12T07:40:47.704369'}
# Sent: {'device_id': 'device001', 'latitude': -18.879538, 'longitude': 47.507494, 'timestamp': '2026-01-12T07:40:49.705547'}
# Sent: {'device_id': 'device001', 'latitude': -18.879512, 'longitude': 47.507456, 'timestamp': '2026-01-12T07:40:51.706569'}
# Sent: {'device_id': 'device001', 'latitude': -18.879486, 'longitude': 47.507418, 'timestamp': '2026-01-12T07:40:53.707809'}
# Sent: {'device_id': 'device001', 'latitude': -18.87946, 'longitude': 47.50738, 'timestamp': '2026-01-12T07:40:55.709408'}
# Sent: {'device_id': 'device001', 'latitude': -18.879434, 'longitude': 47.507342, 'timestamp': '2026-01-12T07:40:57.710640'}
# Sent: {'device_id': 'device001', 'latitude': -18.879408, 'longitude': 47.507304, 'timestamp': '2026-01-12T07:40:59.712464'}
# Sent: {'device_id': 'device001', 'latitude': -18.879382, 'longitude': 47.507266, 'timestamp': '2026-01-12T07:41:01.713681'}
# Sent: {'device_id': 'device001', 'latitude': -18.879356, 'longitude': 47.507228, 'timestamp': '2026-01-12T07:41:03.715434'}
# Sent: {'device_id': 'device001', 'latitude': -18.87933, 'longitude': 47.50719, 'timestamp': '2026-01-12T07:41:05.717330'}
# Sent: {'device_id': 'device001', 'latitude': -18.879304, 'longitude': 47.507152, 'timestamp': '2026-01-12T07:41:07.718996'}
# Sent: {'device_id': 'device001', 'latitude': -18.879278, 'longitude': 47.507114, 'timestamp': '2026-01-12T07:41:09.720827'}
# Sent: {'device_id': 'device001', 'latitude': -18.879252, 'longitude': 47.507076, 'timestamp': '2026-01-12T07:41:11.722277'}
# Sent: {'device_id': 'device001', 'latitude': -18.879226, 'longitude': 47.507038, 'timestamp': '2026-01-12T07:41:13.724488'}
# Sent: {'device_id': 'device001', 'latitude': -18.8792, 'longitude': 47.507, 'timestamp': '2026-01-12T07:41:15.725615'}
