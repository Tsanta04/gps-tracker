# %%
# !pip install paho-mqtt
# Out:
# Collecting paho-mqtt
#   Using cached paho_mqtt-2.1.0-py3-none-any.whl.metadata (23 kB)
# Using cached paho_mqtt-2.1.0-py3-none-any.whl (67 kB)
# Installing collected packages: paho-mqtt
# Successfully installed paho-mqtt-2.1.0
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import time
import json
import random
import ssl
import paho.mqtt.client as mqtt
from datetime import datetime

# %%
BROKER = "e792f3c61e8648d2bd1822c6d1910301.s1.eu.hivemq.cloud"
PORT = 8883
USERNAME = "GPS_ESP"
PASSWORD = "TsantaMirindra1"

DEVICE_ID = "device001"
CLIENT_ID = "location-subscriber"
TOPIC = "iot/"+DEVICE_ID+"/location"

# Position de départ (ex: Antananarivo / Larissa / etc.)
BASE_LAT = -18.8792
BASE_LNG = 47.5079

# %%
def on_connect(client, userdata, flags, rc):
    if rc == 0:
        print("Connected to HiveMQ Cloud")
        print(TOPIC)
    else:
        print(f"Connection failed (code {rc})")

# %%
client = mqtt.Client(client_id=DEVICE_ID)
client.username_pw_set(USERNAME, PASSWORD)
client.tls_set(cert_reqs=ssl.CERT_REQUIRED)

client.on_connect = on_connect
client.connect(BROKER, PORT)
client.loop_start()
# Out:
# C:\Users\WINDOWS 10\AppData\Local\Temp\ipykernel_7984\2261359266.py:1: DeprecationWarning: Callback API version 1 is deprecated, update to latest version
#   client = mqtt.Client(client_id=DEVICE_ID)
# <MQTTErrorCode.MQTT_ERR_SUCCESS: 0>

# %%
# ================= TRAJET =================
GAIOPOLIS = (-18.880500, 47.508900)
CENTRAL_SQUARE = (-18.879200, 47.507000)

STEPS = 50          # nombre de points (plus = plus lent et réaliste)
DELAY = 2           # secondes entre chaque position

try:
    for i in range(STEPS + 1):
        # interpolation linéaire
        lat = GAIOPOLIS[0] + (CENTRAL_SQUARE[0] - GAIOPOLIS[0]) * i / STEPS
        lng = GAIOPOLIS[1] + (CENTRAL_SQUARE[1] - GAIOPOLIS[1]) * i / STEPS

        payload = {
            "device_id": DEVICE_ID,
            "latitude": round(lat, 6),
            "longitude": round(lng, 6),
            "timestamp": datetime.utcnow().isoformat()
        }

        client.publish(TOPIC, json.dumps(payload), qos=1)
        print("Sent:", payload)

        time.sleep(DELAY)

except KeyboardInterrupt:
    print("\nStopped by user")

finally:
    client.loop_stop()
    client.disconnect()
# Out:
# C:\Users\WINDOWS 10\AppData\Local\Temp\ipykernel_7984\2333940416.py:11: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   'timestamp': datetime.utcnow().isoformat()
# Sent: {"device_id": "device001", "latitude": -18.879426, "longitude": 47.507896, "timestamp": "2025-12-19T18:23:50.992996"}
# Connected to HiveMQ Cloud
# iot/device001/location
# Sent: {"device_id": "device001", "latitude": -18.879268, "longitude": 47.507893, "timestamp": "2025-12-19T18:23:52.994236"}
# Sent: {"device_id": "device001", "latitude": -18.879164, "longitude": 47.507614, "timestamp": "2025-12-19T18:23:54.995238"}
# Sent: {"device_id": "device001", "latitude": -18.879049, "longitude": 47.507977, "timestamp": "2025-12-19T18:23:56.998537"}
# Sent: {"device_id": "device001", "latitude": -18.878965, "longitude": 47.508006, "timestamp": "2025-12-19T18:23:59.000438"}
# Sent: {"device_id": "device001", "latitude": -18.879292, "longitude": 47.507651, "timestamp": "2025-12-19T18:24:01.001858"}
# Sent: {"device_id": "device001", "latitude": -18.879001, "longitude": 47.507726, "timestamp": "2025-12-19T18:24:03.005271"}
# Sent: {"device_id": "device001", "latitude": -18.879347, "longitude": 47.507773, "timestamp": "2025-12-19T18:24:05.006076"}
# Sent: {"device_id": "device001", "latitude": -18.878915, "longitude": 47.508077, "timestamp": "2025-12-19T18:24:07.007747"}
# Sent: {"device_id": "device001", "latitude": -18.87916, "longitude": 47.507649, "timestamp": "2025-12-19T18:24:09.009627"}
# Sent: {"device_id": "device001", "latitude": -18.879243, "longitude": 47.507946, "timestamp": "2025-12-19T18:24:11.010956"}
# Sent: {"device_id": "device001", "latitude": -18.87899, "longitude": 47.50815, "timestamp": "2025-12-19T18:24:13.012892"}
# Sent: {"device_id": "device001", "latitude": -18.879265, "longitude": 47.508056, "timestamp": "2025-12-19T18:24:15.014535"}
# Sent: {"device_id": "device001", "latitude": -18.87925, "longitude": 47.507745, "timestamp": "2025-12-19T18:24:17.017511"}
# Sent: {"device_id": "device001", "latitude": -18.87949, "longitude": 47.508192, "timestamp": "2025-12-19T18:24:19.019761"}
# Sent: {"device_id": "device001", "latitude": -18.879095, "longitude": 47.508142, "timestamp": "2025-12-19T18:24:21.022721"}
# Sent: {"device_id": "device001", "latitude": -18.878958, "longitude": 47.50809, "timestamp": "2025-12-19T18:24:23.024377"}
# Sent: {"device_id": "device001", "latitude": -18.879286, "longitude": 47.508094, "timestamp": "2025-12-19T18:24:25.025401"}
# Sent: {"device_id": "device001", "latitude": -18.878931, "longitude": 47.507752, "timestamp": "2025-12-19T18:24:27.026155"}
# Sent: {"device_id": "device001", "latitude": -18.87942, "longitude": 47.507924, "timestamp": "2025-12-19T18:24:29.029217"}
# Sent: {"device_id": "device001", "latitude": -18.879237, "longitude": 47.507631, "timestamp": "2025-12-19T18:24:31.030666"}
# Sent: {"device_id": "device001", "latitude": -18.879049, "longitude": 47.50767, "timestamp": "2025-12-19T18:24:33.032041"}
# Sent: {"device_id": "device001", "latitude": -18.879438, "longitude": 47.507931, "timestamp": "2025-12-19T18:24:35.033525"}
# Sent: {"device_id": "device001", "latitude": -18.879193, "longitude": 47.507794, "timestamp": "2025-12-19T18:24:37.035339"}
# Sent: {"device_id": "device001", "latitude": -18.878973, "longitude": 47.50781, "timestamp": "2025-12-19T18:24:39.039622"}
# Sent: {"device_id": "device001", "latitude": -18.879322, "longitude": 47.507699, "timestamp": "2025-12-19T18:24:41.041954"}
# Sent: {"device_id": "device001", "latitude": -18.879329, "longitude": 47.507918, "timestamp": "2025-12-19T18:24:43.043225"}
# Sent: {"device_id": "device001", "latitude": -18.87921, "longitude": 47.507941, "timestamp": "2025-12-19T18:24:45.045472"}
# Sent: {"device_id": "device001", "latitude": -18.87915, "longitude": 47.508157, "timestamp": "2025-12-19T18:24:47.048309"}
# Sent: {"device_id": "device001", "latitude": -18.879014, "longitude": 47.507706, "timestamp": "2025-12-19T18:24:49.049878"}
# Sent: {"device_id": "device001", "latitude": -18.878927, "longitude": 47.50805, "timestamp": "2025-12-19T18:24:51.051227"}
# Sent: {"device_id": "device001", "latitude": -18.879078, "longitude": 47.507813, "timestamp": "2025-12-19T18:24:53.052658"}
# Sent: {"device_id": "device001", "latitude": -18.879008, "longitude": 47.508063, "timestamp": "2025-12-19T18:24:55.057280"}
# Sent: {"device_id": "device001", "latitude": -18.878992, "longitude": 47.507868, "timestamp": "2025-12-19T18:24:57.058974"}
# Sent: {"device_id": "device001", "latitude": -18.879123, "longitude": 47.507864, "timestamp": "2025-12-19T18:24:59.060754"}
# Sent: {"device_id": "device001", "latitude": -18.879434, "longitude": 47.508189, "timestamp": "2025-12-19T18:25:01.061914"}
# Sent: {"device_id": "device001", "latitude": -18.879066, "longitude": 47.507626, "timestamp": "2025-12-19T18:25:03.065895"}
# Sent: {"device_id": "device001", "latitude": -18.879068, "longitude": 47.507869, "timestamp": "2025-12-19T18:25:05.068130"}
# Sent: {"device_id": "device001", "latitude": -18.879396, "longitude": 47.508011, "timestamp": "2025-12-19T18:25:07.069702"}
# Sent: {"device_id": "device001", "latitude": -18.878966, "longitude": 47.507978, "timestamp": "2025-12-19T18:25:09.071787"}
# Sent: {"device_id": "device001", "latitude": -18.879161, "longitude": 47.508035, "timestamp": "2025-12-19T18:25:11.077649"}
# Sent: {"device_id": "device001", "latitude": -18.878913, "longitude": 47.508109, "timestamp": "2025-12-19T18:25:13.078744"}
# Sent: {"device_id": "device001", "latitude": -18.879252, "longitude": 47.507646, "timestamp": "2025-12-19T18:25:15.079949"}
# Sent: {"device_id": "device001", "latitude": -18.87891, "longitude": 47.508035, "timestamp": "2025-12-19T18:25:17.082727"}
# Sent: {"device_id": "device001", "latitude": -18.87943, "longitude": 47.507676, "timestamp": "2025-12-19T18:25:19.083719"}
# Sent: {"device_id": "device001", "latitude": -18.879191, "longitude": 47.50778, "timestamp": "2025-12-19T18:25:21.084919"}
# Sent: {"device_id": "device001", "latitude": -18.879403, "longitude": 47.507802, "timestamp": "2025-12-19T18:25:23.086225"}
#
# Stopped by user
